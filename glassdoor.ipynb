# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/PlayingNumbers/ds_salary_proj/master/glassdoor_jobs.csv",index_col=0)

# %%
df.head()
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# 2                                KnowBe4\n4.8   Clearwater, FL
# 3                                   PNNL\n3.8     Richland, WA
# 4                     Affinity Solutions\n2.9     New York, NY
#
#      Headquarters                    Size  Founded   Type of ownership  \
# 0      Goleta, CA   501 to 1000 employees     1973   Company - Private
# 1   Baltimore, MD        10000+ employees     1984  Other Organization
# 2  Clearwater, FL   501 to 1000 employees     2010   Company - Private
# 3    Richland, WA  1001 to 5000 employees     1965          Government
# 4    New York, NY     51 to 200 employees     1998   Company - Private
#
#                            Industry                        Sector  \
# 0               Aerospace & Defense           Aerospace & Defense
# 1  Health Care Services & Hospitals                   Health Care
# 2                 Security Services             Business Services
# 3                            Energy  Oil, Gas, Energy & Utilities
# 4           Advertising & Marketing             Business Services
#
#                             Revenue  \
# 0         $50 to $100 million (USD)
# 1            $2 to $5 billion (USD)
# 2        $100 to $500 million (USD)
# 3  $500 million to $1 billion (USD)
# 4          Unknown / Non-Applicable
#
#                                          Competitors
# 0                                                 -1
# 1                                                 -1
# 2                                                 -1
# 3  Oak Ridge National Laboratory, National Renewa...
# 4               Commerce Signals, Cardlytics, Yodlee

# %%
df
# Out:
#                                                    Unnamed: 0  \
# Job Title
# Data Scientist                                              0
# Healthcare Data Scientist                                   1
# Data Scientist                                              2
# Data Scientist                                              3
# Data Scientist                                              4
# ...                                                       ...
# Senior Data Engineer                                      951
# Project Scientist - Auton Lab, Robotics Institute         952
# Data Science Manager                                      953
# Data Engineer                                             954
# Research Scientist – Security and Privacy                 955
#
#                                                                Salary Estimate  \
# Job Title
# Data Scientist                                      $53K-$91K (Glassdoor est.)
# Healthcare Data Scientist                          $63K-$112K (Glassdoor est.)
# Data Scientist                                      $80K-$90K (Glassdoor est.)
# Data Scientist                                      $56K-$97K (Glassdoor est.)
# Data Scientist                                     $86K-$143K (Glassdoor est.)
# ...                                                                        ...
# Senior Data Engineer                               $72K-$133K (Glassdoor est.)
# Project Scientist - Auton Lab, Robotics Institute   $56K-$91K (Glassdoor est.)
# Data Science Manager                               $95K-$160K (Glassdoor est.)
# Data Engineer                                                               -1
# Research Scientist – Security and Privacy          $61K-$126K (Glassdoor est.)
#
#                                                                                      Job Description  \
# Job Title
# Data Scientist                                     Data Scientist\nLocation: Albuquerque, NM\nEdu...
# Healthcare Data Scientist                          What You Will Do:\n\nI. General Summary\n\nThe...
# Data Scientist                                     KnowBe4, Inc. is a high growth information sec...
# Data Scientist                                     *Organization and Job ID**\nJob ID: 310709\n\n...
# Data Scientist                                     Data Scientist\nAffinity Solutions / Marketing...
# ...                                                                                              ...
# Senior Data Engineer                               THE CHALLENGE\nEventbrite has a world-class da...
# Project Scientist - Auton Lab, Robotics Institute  The Auton Lab at Carnegie Mellon University is...
# Data Science Manager                               Data Science ManagerResponsibilities:\n\nOvers...
# Data Engineer                                      Loading...\n\nTitle: Data Engineer\n\nLocation...
# Research Scientist – Security and Privacy          Returning Candidate? Log back in to the Career...
#
#                                                    Rating  \
# Job Title
# Data Scientist                                        3.8
# Healthcare Data Scientist                             3.4
# Data Scientist                                        4.8
# Data Scientist                                        3.8
# Data Scientist                                        2.9
# ...                                                   ...
# Senior Data Engineer                                  4.4
# Project Scientist - Auton Lab, Robotics Institute     2.6
# Data Science Manager                                  3.2
# Data Engineer                                         4.8
# Research Scientist – Security and Privacy             3.6
#
#                                                                                  Company Name  \
# Job Title
# Data Scientist                                                         Tecolote Research\n3.8
# Healthcare Data Scientist                          University of Maryland Medical System\n3.4
# Data Scientist                                                                   KnowBe4\n4.8
# Data Scientist                                                                      PNNL\n3.8
# Data Scientist                                                        Affinity Solutions\n2.9
# ...                                                                                       ...
# Senior Data Engineer                                                          Eventbrite\n4.4
# Project Scientist - Auton Lab, Robotics Institute         Software Engineering Institute\n2.6
# Data Science Manager                                                        Numeric, LLC\n3.2
# Data Engineer                                                                       IGNW\n4.8
# Research Scientist – Security and Privacy                   Riverside Research Institute\n3.6
#
#                                                           Location  \
# Job Title
# Data Scientist                                     Albuquerque, NM
# Healthcare Data Scientist                            Linthicum, MD
# Data Scientist                                      Clearwater, FL
# Data Scientist                                        Richland, WA
# Data Scientist                                        New York, NY
# ...                                                            ...
# Senior Data Engineer                                 Nashville, TN
# Project Scientist - Auton Lab, Robotics Institute   Pittsburgh, PA
# Data Science Manager                                 Allentown, PA
# Data Engineer                                           Austin, TX
# Research Scientist – Security and Privacy          Beavercreek, OH
#
#                                                         Headquarters  \
# Job Title
# Data Scientist                                            Goleta, CA
# Healthcare Data Scientist                              Baltimore, MD
# Data Scientist                                        Clearwater, FL
# Data Scientist                                          Richland, WA
# Data Scientist                                          New York, NY
# ...                                                              ...
# Senior Data Engineer                               San Francisco, CA
# Project Scientist - Auton Lab, Robotics Institute     Pittsburgh, PA
# Data Science Manager                                 Chadds Ford, PA
# Data Engineer                                           Portland, OR
# Research Scientist – Security and Privacy              Arlington, VA
#
#                                                                      Size  \
# Job Title
# Data Scientist                                      501 to 1000 employees
# Healthcare Data Scientist                                10000+ employees
# Data Scientist                                      501 to 1000 employees
# Data Scientist                                     1001 to 5000 employees
# Data Scientist                                        51 to 200 employees
# ...                                                                   ...
# Senior Data Engineer                               1001 to 5000 employees
# Project Scientist - Auton Lab, Robotics Institute   501 to 1000 employees
# Data Science Manager                                    1 to 50 employees
# Data Engineer                                        201 to 500 employees
# Research Scientist – Security and Privacy           501 to 1000 employees
#
#                                                    Founded  \
# Job Title
# Data Scientist                                        1973
# Healthcare Data Scientist                             1984
# Data Scientist                                        2010
# Data Scientist                                        1965
# Data Scientist                                        1998
# ...                                                    ...
# Senior Data Engineer                                  2006
# Project Scientist - Auton Lab, Robotics Institute     1984
# Data Science Manager                                    -1
# Data Engineer                                         2015
# Research Scientist – Security and Privacy             1967
#
#                                                         Type of ownership  \
# Job Title
# Data Scientist                                          Company - Private
# Healthcare Data Scientist                              Other Organization
# Data Scientist                                          Company - Private
# Data Scientist                                                 Government
# Data Scientist                                          Company - Private
# ...                                                                   ...
# Senior Data Engineer                                     Company - Public
# Project Scientist - Auton Lab, Robotics Institute    College / University
# Data Science Manager                                    Company - Private
# Data Engineer                                           Company - Private
# Research Scientist – Security and Privacy          Nonprofit Organization
#
#                                                                            Industry  \
# Job Title
# Data Scientist                                                  Aerospace & Defense
# Healthcare Data Scientist                          Health Care Services & Hospitals
# Data Scientist                                                    Security Services
# Data Scientist                                                               Energy
# Data Scientist                                              Advertising & Marketing
# ...                                                                             ...
# Senior Data Engineer                                                       Internet
# Project Scientist - Auton Lab, Robotics Institute           Colleges & Universities
# Data Science Manager                                         Staffing & Outsourcing
# Data Engineer                                                           IT Services
# Research Scientist – Security and Privacy                          Federal Agencies
#
#                                                                          Sector  \
# Job Title
# Data Scientist                                              Aerospace & Defense
# Healthcare Data Scientist                                           Health Care
# Data Scientist                                                Business Services
# Data Scientist                                     Oil, Gas, Energy & Utilities
# Data Scientist                                                Business Services
# ...                                                                         ...
# Senior Data Engineer                                     Information Technology
# Project Scientist - Auton Lab, Robotics Institute                     Education
# Data Science Manager                                          Business Services
# Data Engineer                                            Information Technology
# Research Scientist – Security and Privacy                            Government
#
#                                                                             Revenue  \
# Job Title
# Data Scientist                                            $50 to $100 million (USD)
# Healthcare Data Scientist                                    $2 to $5 billion (USD)
# Data Scientist                                           $100 to $500 million (USD)
# Data Scientist                                     $500 million to $1 billion (USD)
# Data Scientist                                             Unknown / Non-Applicable
# ...                                                                             ...
# Senior Data Engineer                                     $100 to $500 million (USD)
# Project Scientist - Auton Lab, Robotics Institute          Unknown / Non-Applicable
# Data Science Manager                                        $5 to $10 million (USD)
# Data Engineer                                              $25 to $50 million (USD)
# Research Scientist – Security and Privacy                 $50 to $100 million (USD)
#
#                                                                                          Competitors
# Job Title
# Data Scientist                                                                                    -1
# Healthcare Data Scientist                                                                         -1
# Data Scientist                                                                                    -1
# Data Scientist                                     Oak Ridge National Laboratory, National Renewa...
# Data Scientist                                                  Commerce Signals, Cardlytics, Yodlee
# ...                                                                                              ...
# Senior Data Engineer                                                 See Tickets, TicketWeb, Vendini
# Project Scientist - Auton Lab, Robotics Institute                                                 -1
# Data Science Manager                                                                              -1
# Data Engineer                                                                                 Slalom
# Research Scientist – Security and Privacy                                                         -1
#
# [956 rows x 14 columns]
